# %% [markdown]
# <a href="https://colab.research.google.com/github/yuanjinren/DS/blob/master/AD_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nibabel as nb
import skimage.io as io
import numpy as np

# %%
nb.Nifti1Header
# Out:
# nibabel.nifti1.Nifti1Header

# %%
img=nb.load('/content/ADNI_133_S_1170_MR_MPR__GradWarp__B1_Correction__N3__Scaled_Br_20080207174424754_S24674_I89957.nii')

# %%
img.shape
# Out:
# (256, 256, 166)

# %%
print(img)
# Out:
# <class 'nibabel.nifti1.Nifti1Image'>
# data shape (256, 256, 166)
# affine:
# [[ 3.23237664e-08  2.48079818e-04 -1.20282896e+00  9.89999008e+01]
#  [-2.47078995e-04 -9.48146159e-01 -3.14716857e-04  1.48070007e+02]
#  [-9.44351224e-01  2.48071906e-04  4.11710828e-08  8.65595016e+01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# metadata:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='>'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b'133_S_1170'
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 0
# dim             : [  3 256 256 166   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.         0.94435126 0.9481462  1.202829   1.         1.
#  1.         1.        ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# ...

# %%
hdr = img.header

# %%
hdr.get_xyzt_units()
# Out:
# ('mm', 'unknown')

# %%
type(img)
# Out:
# nibabel.nifti1.Nifti1Image

# %%
img.get_data_dtype()
# Out:
# dtype('>f4')

# %%
img.affine.shape
# Out:
# (4, 4)

# %%
img_arr=img.get_fdata()

# %%
img_arr.shape
# Out:
# (256, 256, 166)

# %%
type(img_arr)
# Out:
# numpy.memmap

# %%
import matplotlib.pyplot as plt
plt.imshow(img_arr[:,img_arr.shape[1]//2, :].T, cmap='Greys_r');

# %%
plt.imshow(img_arr[:,:,img_arr.shape[2]//2].T, cmap='Greys_r');

# %%
def show_slices(slices):
   """ Function to display row of image slices """
   fig, axes = plt.subplots(1, len(slices))
   for i, slice in enumerate(slices):
       axes[i].imshow(slice.T, cmap="gray", origin="lower")

slice_0 = img_arr[128, :, :]
slice_1 = img_arr[:, 128, :]
slice_2 = img_arr[:, :, 83]
show_slices([slice_0, slice_1, slice_2])
plt.suptitle("Center slices for EPI image");
