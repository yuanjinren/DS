# %% [markdown]
# <a href="https://colab.research.google.com/github/yuanjinren/DS/blob/master/Pandas_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'https://drive.google.com/uc?export=download&id=1fL7KPyxgGYfQDsuJoBWHIWwCAf-HTFpX'
df = pd.read_csv(url,index_col='game_id')

# %%
df.head()
# Out:
#           game_event_id    player_name  ...     season_type  scoremargin_before_shot
# game_id                                 ...
# 20900015              4  Stephen Curry  ...  Regular Season                      2.0
# 20900015             17  Stephen Curry  ...  Regular Season                      0.0
# 20900015             53  Stephen Curry  ...  Regular Season                     -4.0
# 20900015            141  Stephen Curry  ...  Regular Season                     -4.0
# 20900015            249  Stephen Curry  ...  Regular Season                      0.0
#
# [5 rows x 19 columns]

# %%
df.index
# Out:
# Int64Index([20900015, 20900015, 20900015, 20900015, 20900015, 20900015,
#             20900015, 20900015, 20900015, 20900015,
#             ...
#             41800403, 41800403, 41800403, 41800403, 41800403, 41800403,
#             41800403, 41800403, 41800403, 41800403],
#            dtype='int64', name='game_id', length=13958)

# %%
df.set_index('game_event_id',inplace=True)
df.head()
# Out:
#                  player_name  period  ...     season_type  scoremargin_before_shot
# game_event_id                         ...
# 4              Stephen Curry       1  ...  Regular Season                      2.0
# 17             Stephen Curry       1  ...  Regular Season                      0.0
# 53             Stephen Curry       1  ...  Regular Season                     -4.0
# 141            Stephen Curry       2  ...  Regular Season                     -4.0
# 249            Stephen Curry       2  ...  Regular Season                      0.0
#
# [5 rows x 18 columns]

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#    game_event_id    player_name  ...     season_type  scoremargin_before_shot
# 0              4  Stephen Curry  ...  Regular Season                      2.0
# 1             17  Stephen Curry  ...  Regular Season                      0.0
# 2             53  Stephen Curry  ...  Regular Season                     -4.0
# 3            141  Stephen Curry  ...  Regular Season                     -4.0
# 4            249  Stephen Curry  ...  Regular Season                      0.0
#
# [5 rows x 19 columns]

# %%
df.sort_index(ascending=True)
# Out:
#        game_event_id    player_name  ...     season_type  scoremargin_before_shot
# 0                  4  Stephen Curry  ...  Regular Season                      2.0
# 1                 17  Stephen Curry  ...  Regular Season                      0.0
# 2                 53  Stephen Curry  ...  Regular Season                     -4.0
# 3                141  Stephen Curry  ...  Regular Season                     -4.0
# 4                249  Stephen Curry  ...  Regular Season                      0.0
# ...              ...            ...  ...             ...                      ...
# 13953            570  Stephen Curry  ...        Playoffs                    -13.0
# 13954            573  Stephen Curry  ...        Playoffs                    -14.0
# 13955            602  Stephen Curry  ...        Playoffs                    -17.0
# 13956            608  Stephen Curry  ...        Playoffs                    -16.0
# ...

# %%
df.iloc[0:4,1:4] # the 4th row and the 4th column not included
# Out:
#      player_name  period  minutes_remaining
# 0  Stephen Curry       1                 11
# 1  Stephen Curry       1                  9
# 2  Stephen Curry       1                  6
# 3  Stephen Curry       2                  9

# %%
df.set_index('game_event_id',inplace=True)

# %%
df.head()
# Out:
#                  player_name  period  ...     season_type  scoremargin_before_shot
# game_event_id                         ...
# 4              Stephen Curry       1  ...  Regular Season                      2.0
# 17             Stephen Curry       1  ...  Regular Season                      0.0
# 53             Stephen Curry       1  ...  Regular Season                     -4.0
# 141            Stephen Curry       2  ...  Regular Season                     -4.0
# 249            Stephen Curry       2  ...  Regular Season                      0.0
#
# [5 rows x 18 columns]

# %%
df.sort_index()
# Out:
#                  player_name  period  ...     season_type  scoremargin_before_shot
# game_event_id                         ...
# 2              Stephen Curry       1  ...  Regular Season                     -0.0
# 2              Stephen Curry       1  ...  Regular Season                     -0.0
# 2              Stephen Curry       1  ...  Regular Season                      0.0
# 2              Stephen Curry       1  ...  Regular Season                      0.0
# 2              Stephen Curry       1  ...  Regular Season                      0.0
# ...                      ...     ...  ...             ...                      ...
# 739            Stephen Curry       4  ...        Playoffs                      0.0
# 741            Stephen Curry       5  ...  Regular Season                     -4.0
# 747            Stephen Curry       5  ...  Regular Season                      4.0
# 751            Stephen Curry       4  ...        Playoffs                     -2.0
# ...

# %%
df.loc[[2,3,4], ['player_name','period','action_type']]
# Out:
#                  player_name  period          action_type
# game_event_id
# 2              Stephen Curry       1     Pullup Jump shot
# 2              Stephen Curry       1     Pullup Jump shot
# 2              Stephen Curry       1            Jump Shot
# 2              Stephen Curry       1            Jump Shot
# 2              Stephen Curry       1            Jump Shot
# ...                      ...     ...                  ...
# 4              Stephen Curry       1            Jump Shot
# 4              Stephen Curry       1            Jump Shot
# 4              Stephen Curry       1            Jump Shot
# 4              Stephen Curry       1  Step Back Jump shot
# 4              Stephen Curry       1   Floating Jump shot
#
# [79 rows x 3 columns]

# %%
student = {
    'student_ID': [1123451, 2341567,2349807],
    'student_name':['Steven','George','Jimmy'],
    'grade':['A','A+','B']
}

# %%
type(student)
# Out:
# dict

# %%
df_student=pd.DataFrame(student)
df_student
# Out:
#    student_ID student_name grade
# 0     1123451       Steven     A
# 1     2341567       George    A+
# 2     2349807        Jimmy     B

# %%
type(df_student['grade'])
# Out:
# pandas.core.series.Series

# %%
type(df_student)
# Out:
# pandas.core.frame.DataFrame
